# %%
# !pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\anaconda\lib\site-packages (0.0.62)
# Requirement already satisfied: tqdm>=4.30.0 in c:\anaconda\lib\site-packages (from deepface) (4.50.2)
# Requirement already satisfied: Flask>=1.1.2 in c:\anaconda\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\anaconda\lib\site-packages (from deepface) (2.5.0)
# Requirement already satisfied: keras>=2.2.0 in c:\anaconda\lib\site-packages (from deepface) (2.4.3)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\anaconda\lib\site-packages (from deepface) (0.1.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\anaconda\lib\site-packages (from deepface) (0.0.4)
# Requirement already satisfied: Pillow>=5.2.0 in c:\anaconda\lib\site-packages (from deepface) (8.0.1)
# Requirement already satisfied: gdown>=3.10.1 in c:\anaconda\lib\site-packages (from deepface) (3.13.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\anaconda\lib\site-packages (from deepface) (1.19.2)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\anaconda\lib\site-packages (from deepface) (4.5.2.54)
# Requirement already satisfied: pandas>=0.23.4 in c:\anaconda\lib\site-packages (from deepface) (1.1.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.13.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.5.0.dev2021032900)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.5.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.35.1)
# Requirement already satisfied: google-pasta~=0.2 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: gast==0.4.0 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.15.0)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Requirement already satisfied: termcolor~=1.1.0 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: tensorboard~=2.5 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.5.0)
# Requirement already satisfied: grpcio~=1.34.0 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.34.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.17.3)
# Requirement already satisfied: scipy>=0.14 in c:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (1.5.2)
# Requirement already satisfied: pyyaml in c:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (5.3.1)
# Requirement already satisfied: filelock in c:\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: requests[socks]>=2.12.0 in c:\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (2.24.0)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\anaconda\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\anaconda\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (50.3.1.post20201107)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\anaconda\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\anaconda\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\anaconda\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (1.32.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\anaconda\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (1.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\anaconda\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (3.1.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\anaconda\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.9.0->deepface) (0.4.8)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# Successfully installed h5py-3.1.0

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread('happyboy.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
pred = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.38it/s]

# %%
pred
# Out:
# {'emotion': {'angry': 4.448926073656435e-15,
#   'disgust': 2.9562202702584637e-20,
#   'fear': 3.620682143587028e-13,
#   'happy': 99.99994039535522,
#   'sad': 1.4509458901284383e-11,
#   'surprise': 1.7431130323875e-10,
#   'neutral': 6.36651918739517e-05},
#  'dominant_emotion': 'happy',
#  'region': {'x': 246, 'y': 226, 'w': 530, 'h': 530},
#  'age': 21,
#  'gender': 'Man',
#  'race': {'asian': 0.006114703138761224,
#   'indian': 0.052228238606093956,
#   'black': 0.0013055211376170215,
#   'white': 82.274416956236,
#   'middle eastern': 10.852988613008096,
#   'latino hispanic': 6.812950290793215},
#  'dominant_race': 'white'}

# %%
facecascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %% [markdown]
# # Drawing rectangle around face

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, 
                pred['dominant_emotion'], 
                (0, 50), 
                font, 1, 
                (0, 0, 255), 
                 2, 
                cv2.LINE_4);

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces= facecascade.detectMultiScale(gray ,1.1,4)
for (a,b,c,d) in faces:
    cv2.rectangle(img, (a,b) , (a+c, b+d), (0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(frame, 
                pred['dominant_emotion'], 
                (0, 50), 
                font, 1, 
                (0, 0, 255), 
                 2, 
                cv2.LINE_4);
  # Display the resulting frame
cv2.imshow('video', frame)
  
    # creating 'q' as the quit 
    # button for the video
        if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  
        cap.release()
# close all windows
        cv2.destroyAllWindows()
# Out:
#   File "<ipython-input-39-3a287295e373>", line 14
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # real time demo video for dace recognition

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

facecascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
while(True):
      
    # Capture frames in the video
    ret, frame = cap.read()
    result= DeepFace.analyze(frame, actions= ['emotion'])
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces= facecascade.detectMultiScale(gray ,1.1,4)
    for (a,b,c,d) in faces:
        cv2.rectangle(frame, (a,b) , (a+c, b+d), (0,255,0),2)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, 
                    pred['dominant_emotion'], 
                    (0, 50), 
                    font, 1, 
                    (0, 0, 255), 
                     2, 
                    cv2.LINE_4);
    cv2.imshow('video', frame)

   
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.31it/s]
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.32it/s]
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.37it/s]
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.31it/s]
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.22it/s]
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ee1fe9b8b11e> in <module>
#      10     # Capture frames in the video
#      11     ret, frame = cap.read()
# ---> 12     result= DeepFace.analyze(frame, actions= ['emotion'])
#      13     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      14     faces= facecascade.detectMultiScale(gray ,1.1,4)
#
# C:\anaconda\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend)
#     377                         if action == 'emotion':
#     378                                 emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 379                                 img, region = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     380
#     381                                 emotion_predictions = models['emotion'].predict(img)[0,:]
#
# C:\anaconda\lib\site-packages\deepface\commons\functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
#     109         base_img = img.copy()
#     110
# --> 111         img, region = detect_face(img = img, detector_backend = detector_backend, grayscale = grayscale, enforce_detection = enforce_detection, align = align)
#     112
#     113         #--------------------------
#
# C:\anaconda\lib\site-packages\deepface\commons\functions.py in detect_face(img, detector_backend, grayscale, enforce_detection, align)
#     101                           return img, img_region
#     102                         else:
# --> 103                           raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
#     104
#     105 def preprocess_face(img, target_size=(224, 224), grayscale = False, enforce_detection = True, detector_backend = 'opencv', return_region = False, align = True):
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
